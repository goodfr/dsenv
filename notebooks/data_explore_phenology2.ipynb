# %% [markdown]
# ## Phenology analysis

# %% [markdown]
# The purpose of the study is to predict phenological status of flowers. Data comes from [tela-botanica](https://referentiels.tela-botanica.org/)

# %%
import pandas as pd

# %%
df = pd.read_parquet(path="../data/02_ods_telabotanica_with_weather_data.parquet")

# %%
df
# Out:
#              date  annee  jour_de_l_annee  n_site  \
# 0      2024-03-27   2024               87   38269
# 1      2024-03-27   2024               87   38269
# 2      2024-03-25   2024               85  393433
# 3      2024-03-25   2024               85  393433
# 4      2024-03-25   2024               85  393433
# ...           ...    ...              ...     ...
# 23495  2007-03-05   2007               64   37284
# 23496  2007-03-05   2007               64   37284
# 23497  2007-02-12   2007               43   37321
# 23498  2007-01-29   2007               29   37284
# 23499  2007-01-29   2007               29   37284
#
#                             nom_site  latitude_site  longitude_site  \
# 0             angouleme-pierre-levee        45.6328         0.15512
# 1             angouleme-pierre-levee        45.6328         0.15512
# 2      saint-martin-des-puits-jardin        43.0404         2.56752
# 3      saint-martin-des-puits-jardin        43.0404         2.56752
# ...
